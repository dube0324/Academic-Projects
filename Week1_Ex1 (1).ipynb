# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import matplotlib.pyplot  as plt

# %%
#Q1 Write a user defined function ‘myFnLinReg(x,y)’ to perform Simple Linear 
#Regression given one predictor attribute and one response attribute. The 
#function should return the coefficients of the straight line.
def myFnLinReg(x,y):
    mx = np.mean(x)
    my = np.mean(y)
    b1_numerator = ((x - mx) * (y - my)).sum()
    b1_denominator = ((x - mx) ** 2).sum()
    b1 = b1_numerator / b1_denominator
    b0 = my - (b1 * mx)
    return (b0, b1)

# %%
#Q2 Use mtcars data set and consider the attributes mpg and weight. Split data into 
#train and test sets (70 %,30%). Put training data set to ‘myFnLinReg(x,y)’ to 
#build a linear regression model to predict mpg given the weight of the car.

df = pd.read_csv("mtcars.csv")
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
X = df.wt
X = np.array(X)
Y = df.mpg
Y = np.array(Y)

# %%
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size = 0.3, random_state = 4389)
b0, b1 = myFnLinReg(train_x,train_y)

# %%
print("y = {} + {}x".format(round(b0, 4), round(b1, 4)))
# Out:
# y = 39.8039 + -6.1656x

# %%
plt.scatter(train_x, train_y)
plt.plot(train_x, b0 + b1*train_x)
plt.xlabel("Weight of car")
plt.ylabel("Miles per gallon")
# Out:
# Text(0, 0.5, 'Miles per gallon')

# %%
def predict(b0, b1, test_x):
    y = b0 + b1*test_x
    return y
pred_y = predict(b0,b1,test_x)
print(pred_y)
# Out:
# [22.0777321  27.87342715 17.79261714 20.13555769 20.25887035  6.84861851
#  18.59414944 25.49965843 29.84642972  7.43435365]

# %%
#Q3 What is the mpg of a car, whose weight is 6.7?
print("The mpg of car with weight 6.7 is", round(predict(b0, b1, 6.7), 4))
# Out:
# The mpg of car with weight 6.7 is -1.5058

# %%
#Q4 Compute and print accuracy measures such as RMSE and R2 for the test set.
def calculateRMSE_R2(test_y, pred_y):
    n = len(test_x)
    RMSE = mean_squared_error(pred_y, test_y)**0.5
    R2 = r2_score(pred_y, test_y)
    return RMSE, R2
calculateRMSE_R2(test_y, pred_y)
# Out:
# (3.6077221736705214, 0.7544080681892249)

# %%
#Q5 Apply the stochastic gradient descent and mini batch gradient descent 
#algorithms to enhance the accuracy and visualize the cost function.
def SGD(x_train, y_train, alpha = 0.006, m = 10000):
    t0 = 0
    t1 = 0
    for i in range(m):
        y_i = t0 + t1 * x_train
        t0 = t0 - (alpha * sum(y_i - y_train)) / len(x_train)
        t1 = t1 - (alpha * sum((y_i - y_train) * x_train)) / len(x_train)
    return t0, t1, y_i

# %%
g, h, i = SGD(train_x, train_y, alpha = 0.1, m = 10000)
print(g, h)
# Out:
# 39.803927060486004 -6.165633030532913

# %%
plt.scatter(train_x, train_y)
plt.plot(train_x, i, color = 'red')
plt.xlabel( "Experience (in years)" )
plt.ylabel( "Salary (in rupees)" )
plt.show()

# %%
def MiniBatch(X_train,Y_train, batch_size):
        
    coeff = {}
    costs = []
    
    alpha = 0.1
    epochs = 10000
    
    M = X_train.shape[0]
    w = np.random.randn()
    b = 0
    
    batches = M/batch_size
    
    flag = 0
    
    if batches > int(batches):
        flag = 1
    
    batches = int(batches)
    
    for epoch in range(epochs):
        
        batch = 0
        
        m_b_costs = []
        
        while batch < batches:
            
            X = X_train[batch*batch_size: (batch+1)*batch_size]
            Y = Y_train[batch*batch_size: (batch+1)*batch_size]
            
            h = w*X + b
        
            J = (1/(2*M))*(((h - Y)*2).sum())

            costs.append(J)

            dw = (1/M)*(((h - Y).dot(X)).sum())

            db = (1/M)*((h - Y).sum())

            w = w - alpha * dw
            b = b - alpha * db
            
            batch += 1
        
        if flag == 1:
            X = X_train[batch*batch_size:]
            
            h = w*X_train + b
            
            J = (1/(2*M))(((h - Y_train)*2).sum())
            
            costs.append(J)
            
            dw = (1/M)*(((h - Y_train).dot(X_train)).sum())
            
            db = (1/M)*((h - Y_train).sum())
        

        w = w - alpha * dw
        b = b - alpha * db
          
    coeff["theta"] = w
    coeff["bias"] =  b
    
    return coeff, costs

# %%
coeff, costs = MiniBatch(train_x, train_y, 5)
print(coeff)
# Out:
# {'theta': -5.861951379256664, 'bias': 38.230490153969065}
